# %%
#Install all python packages with: pip install package
import ast
import time
import flopy
import numpy as np
import geopandas as gpd
from shapely.geometry import Polygon
from PySAGA_cmd import SAGA
import whitebox
from shapely.geometry import Point, LineString, MultiPoint
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.colors import TwoSlopeNorm
from collections import defaultdict
import pandas as pd
from concurrent.futures import ProcessPoolExecutor
import os
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)


#Link your GW results
#Input 1) Model Results, with name "modelo"and "version" 
modelo="Model_12" ### Change for your model name###
version= "12.136" ### Define your number model
epgs="EPSG:32719" ### change for your epgs number###
modelName = f'Model_v{version}'
modelWs = os.path.join(modelo, f"Sim_{version}")
model_path = os.path.join('C:/Users/nick_/OneDrive/Escritorio/Postgrado/Tesis/MODELMUSE',modelWs) #Cambiar a tu directorio donde estan inputs y outputs de mf6

#For Calibration with Springs
calib_manan_input=r'C:\Users\nick_\OneDrive\Escritorio\Raster'  #Change for your calibration_spring files path, already create with DEM input
calib_manan_path =os.path.join(calib_manan_input,'calib_output') #output
os.makedirs(calib_manan_path, exist_ok=True)
calib_man = f'Calib_Manan_Sim_{version}'

# %%
#help(function) if you have questions in whiteboxtools
wbt = whitebox.WhiteboxTools()
wbt.set_verbose_mode(True)

#INPUT Paths

#Input 2) DEM (for drainage network and d8_pointer)
#DEM with SRC ready for your targets, here is epgs:32719
DEM=os.path.join(calib_manan_input,"DEM.tif")

#Input 3) Shapefile of Dominium
dom=os.path.join(calib_manan_input,'Dominium.shp')

#Input 4) Shapefile of springs (points)
original_points = os.path.join(calib_manan_input,'Springs.shp')

#OUTPUTS Paths
DEM_OUT=os.path.join(calib_manan_path,"DEM_OUT.tif")
FP=os.path.join(calib_manan_path,"FP.tif")
FA=os.path.join(calib_manan_path,"FA.tif")
Stream_raster1=os.path.join(calib_manan_path,"STREAM.tif")
drainage_network=os.path.join(calib_manan_path,"drainage_network.shp")

#wbt work
wbt.flow_accumulation_full_workflow(dem=DEM,out_dem=DEM_OUT,out_pntr=FP,out_accum=FA,out_type='cells') #FA with cells

wbt.extract_streams(flow_accum=FA,output=Stream_raster1,threshold=1000) #Create Raster of drainage network with minimum threshold =1, trying with largest number, if you use 1 for a big regional DEM will take time

wbt.raster_streams_to_vector(Stream_raster1,FP,output=drainage_network) #Create Shape of drainage network
# Out:
# .\whitebox_tools.exe --run="FlowAccumulationFullWorkflow" --dem='C:\Users\nick_\OneDrive\Escritorio\Raster\DEM.tif' --out_dem='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\DEM_OUT.tif' --out_pntr='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FP.tif' --out_accum='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FA.tif' --out_type=cells -v --compress_rasters=False
#
# *******************************************
# * Welcome to FlowAccumulationFullWorkflow *
# * Powered by WhiteboxTools                *
# * www.whiteboxgeo.com                     *
# *******************************************
# Reading data...
# Calculating aspect: 0%
# Calculating aspect: 1%
# Calculating aspect: 2%
# Calculating aspect: 3%
# Calculating aspect: 4%
# Calculating aspect: 5%
# Calculating aspect: 6%
# Calculating aspect: 7%
# Calculating aspect: 8%
# Calculating aspect: 9%
# Calculating aspect: 10%
# Calculating aspect: 11%
# Calculating aspect: 12%
# Calculating aspect: 13%
# Calculating aspect: 14%
# Calculating aspect: 15%
# Calculating aspect: 16%
# Calculating aspect: 17%
# Calculating aspect: 18%
# Calculating aspect: 19%
# Calculating aspect: 20%
# Calculating aspect: 21%
# Calculating aspect: 22%
# Calculating aspect: 23%
# Calculating aspect: 24%
# Calculating aspect: 25%
# Calculating aspect: 26%
# Calculating aspect: 27%
# Calculating aspect: 28%
# Calculating aspect: 29%
# Calculating aspect: 30%
# Calculating aspect: 31%
# Calculating aspect: 32%
# Calculating aspect: 33%
# Calculating aspect: 34%
# Calculating aspect: 35%
# Calculating aspect: 36%
# Calculating aspect: 37%
# Calculating aspect: 38%
# Calculating aspect: 39%
# Calculating aspect: 40%
# Calculating aspect: 41%
# Calculating aspect: 42%
# Calculating aspect: 43%
# Calculating aspect: 44%
# Calculating aspect: 45%
# Calculating aspect: 46%
# Calculating aspect: 47%
# Calculating aspect: 48%
# Calculating aspect: 49%
# Calculating aspect: 50%
# Calculating aspect: 51%
# Calculating aspect: 52%
# Calculating aspect: 53%
# Calculating aspect: 54%
# Calculating aspect: 55%
# Calculating aspect: 56%
# Calculating aspect: 57%
# Calculating aspect: 58%
# Calculating aspect: 59%
# Calculating aspect: 60%
# Calculating aspect: 61%
# Calculating aspect: 62%
# Calculating aspect: 63%
# Calculating aspect: 64%
# Calculating aspect: 65%
# Calculating aspect: 66%
# Calculating aspect: 67%
# Calculating aspect: 68%
# Calculating aspect: 69%
# Calculating aspect: 70%
# Calculating aspect: 71%
# Calculating aspect: 72%
# Calculating aspect: 73%
# Calculating aspect: 74%
# Calculating aspect: 75%
# Calculating aspect: 76%
# Calculating aspect: 77%
# Calculating aspect: 78%
# Calculating aspect: 79%
# Calculating aspect: 80%
# Calculating aspect: 81%
# Calculating aspect: 82%
# Calculating aspect: 83%
# Calculating aspect: 84%
# Calculating aspect: 85%
# Calculating aspect: 86%
# Calculating aspect: 87%
# Calculating aspect: 88%
# Calculating aspect: 89%
# Calculating aspect: 90%
# Calculating aspect: 91%
# Calculating aspect: 92%
# Calculating aspect: 93%
# Calculating aspect: 94%
# Calculating aspect: 95%
# Calculating aspect: 96%
# Calculating aspect: 97%
# Calculating aspect: 98%
# Calculating aspect: 99%
# Calculating aspect: 100%
# progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Saving DEM data...
# Output file written
# Num. inflowing neighbours: 0%
# Num. inflowing neighbours: 1%
# Num. inflowing neighbours: 2%
# Num. inflowing neighbours: 3%
# Num. inflowing neighbours: 4%
# Num. inflowing neighbours: 5%
# Num. inflowing neighbours: 6%
# Num. inflowing neighbours: 7%
# Num. inflowing neighbours: 8%
# Num. inflowing neighbours: 9%
# Num. inflowing neighbours: 10%
# Num. inflowing neighbours: 11%
# Num. inflowing neighbours: 12%
# Num. inflowing neighbours: 13%
# Num. inflowing neighbours: 14%
# Num. inflowing neighbours: 15%
# Num. inflowing neighbours: 16%
# Num. inflowing neighbours: 17%
# Num. inflowing neighbours: 18%
# Num. inflowing neighbours: 19%
# Num. inflowing neighbours: 20%
# Num. inflowing neighbours: 21%
# Num. inflowing neighbours: 22%
# Num. inflowing neighbours: 23%
# Num. inflowing neighbours: 24%
# Num. inflowing neighbours: 25%
# Num. inflowing neighbours: 26%
# Num. inflowing neighbours: 27%
# Num. inflowing neighbours: 28%
# Num. inflowing neighbours: 29%
# Num. inflowing neighbours: 30%
# Num. inflowing neighbours: 31%
# Num. inflowing neighbours: 32%
# Num. inflowing neighbours: 33%
# Num. inflowing neighbours: 34%
# Num. inflowing neighbours: 35%
# Num. inflowing neighbours: 36%
# Num. inflowing neighbours: 37%
# Num. inflowing neighbours: 38%
# Num. inflowing neighbours: 39%
# Num. inflowing neighbours: 40%
# Num. inflowing neighbours: 41%
# Num. inflowing neighbours: 42%
# Num. inflowing neighbours: 43%
# Num. inflowing neighbours: 44%
# Num. inflowing neighbours: 45%
# Num. inflowing neighbours: 46%
# Num. inflowing neighbours: 47%
# Num. inflowing neighbours: 48%
# Num. inflowing neighbours: 49%
# Num. inflowing neighbours: 50%
# Num. inflowing neighbours: 51%
# Num. inflowing neighbours: 52%
# Num. inflowing neighbours: 53%
# Num. inflowing neighbours: 54%
# Num. inflowing neighbours: 55%
# Num. inflowing neighbours: 56%
# Num. inflowing neighbours: 57%
# Num. inflowing neighbours: 58%
# Num. inflowing neighbours: 59%
# Num. inflowing neighbours: 60%
# Num. inflowing neighbours: 61%
# Num. inflowing neighbours: 62%
# Num. inflowing neighbours: 63%
# Num. inflowing neighbours: 64%
# Num. inflowing neighbours: 65%
# Num. inflowing neighbours: 66%
# Num. inflowing neighbours: 67%
# Num. inflowing neighbours: 68%
# Num. inflowing neighbours: 69%
# Num. inflowing neighbours: 70%
# Num. inflowing neighbours: 71%
# Num. inflowing neighbours: 72%
# Num. inflowing neighbours: 73%
# Num. inflowing neighbours: 74%
# Num. inflowing neighbours: 75%
# Num. inflowing neighbours: 76%
# Num. inflowing neighbours: 77%
# Num. inflowing neighbours: 78%
# Num. inflowing neighbours: 79%
# Num. inflowing neighbours: 80%
# Num. inflowing neighbours: 81%
# Num. inflowing neighbours: 82%
# Num. inflowing neighbours: 83%
# Num. inflowing neighbours: 84%
# Num. inflowing neighbours: 85%
# Num. inflowing neighbours: 86%
# Num. inflowing neighbours: 87%
# Num. inflowing neighbours: 88%
# Num. inflowing neighbours: 89%
# Num. inflowing neighbours: 90%
# Num. inflowing neighbours: 91%
# Num. inflowing neighbours: 92%
# Num. inflowing neighbours: 93%
# Num. inflowing neighbours: 94%
# Num. inflowing neighbours: 95%
# Num. inflowing neighbours: 96%
# Num. inflowing neighbours: 97%
# Num. inflowing neighbours: 98%
# Num. inflowing neighbours: 99%
# Num. inflowing neighbours: 100%
# Flow accumulation: 0%
# Flow accumulation: 1%
# Flow accumulation: 2%
# Flow accumulation: 3%
# Flow accumulation: 4%
# Flow accumulation: 5%
# Flow accumulation: 6%
# Flow accumulation: 7%
# Flow accumulation: 8%
# Flow accumulation: 9%
# Flow accumulation: 10%
# Flow accumulation: 11%
# Flow accumulation: 12%
# Flow accumulation: 13%
# Flow accumulation: 14%
# Flow accumulation: 15%
# Flow accumulation: 16%
# Flow accumulation: 17%
# Flow accumulation: 18%
# Flow accumulation: 19%
# Flow accumulation: 20%
# Flow accumulation: 21%
# Flow accumulation: 22%
# Flow accumulation: 23%
# Flow accumulation: 24%
# Flow accumulation: 25%
# Flow accumulation: 26%
# Flow accumulation: 27%
# Flow accumulation: 28%
# Flow accumulation: 29%
# Flow accumulation: 30%
# Flow accumulation: 31%
# Flow accumulation: 32%
# Flow accumulation: 33%
# Flow accumulation: 34%
# Flow accumulation: 35%
# Flow accumulation: 36%
# Flow accumulation: 37%
# Flow accumulation: 38%
# Flow accumulation: 39%
# Flow accumulation: 40%
# Flow accumulation: 41%
# Flow accumulation: 42%
# Flow accumulation: 43%
# Flow accumulation: 44%
# Flow accumulation: 45%
# Flow accumulation: 46%
# Flow accumulation: 47%
# Flow accumulation: 48%
# Flow accumulation: 49%
# Flow accumulation: 50%
# Flow accumulation: 51%
# Flow accumulation: 52%
# Flow accumulation: 53%
# Flow accumulation: 54%
# Flow accumulation: 55%
# Flow accumulation: 56%
# Flow accumulation: 57%
# Flow accumulation: 58%
# Flow accumulation: 59%
# Flow accumulation: 60%
# Flow accumulation: 61%
# Flow accumulation: 62%
# Flow accumulation: 63%
# Flow accumulation: 64%
# Flow accumulation: 65%
# Flow accumulation: 66%
# Flow accumulation: 67%
# Flow accumulation: 68%
# Flow accumulation: 69%
# Flow accumulation: 70%
# Flow accumulation: 71%
# Flow accumulation: 72%
# Flow accumulation: 73%
# Flow accumulation: 74%
# Flow accumulation: 75%
# Flow accumulation: 76%
# Flow accumulation: 77%
# Flow accumulation: 78%
# Flow accumulation: 79%
# Flow accumulation: 80%
# Flow accumulation: 81%
# Flow accumulation: 82%
# Flow accumulation: 83%
# Flow accumulation: 84%
# Flow accumulation: 85%
# Flow accumulation: 86%
# Flow accumulation: 87%
# Flow accumulation: 88%
# Flow accumulation: 89%
# Flow accumulation: 90%
# Flow accumulation: 91%
# Flow accumulation: 92%
# Flow accumulation: 93%
# Flow accumulation: 94%
# Flow accumulation: 95%
# Flow accumulation: 96%
# Flow accumulation: 97%
# Flow accumulation: 98%
# Flow accumulation: 99%
# Flow accumulation: 100%
# Correcting values: 0%
# Correcting values: 1%
# Correcting values: 2%
# Correcting values: 3%
# Correcting values: 4%
# Correcting values: 5%
# Correcting values: 6%
# Correcting values: 7%
# Correcting values: 8%
# Correcting values: 9%
# Correcting values: 10%
# Correcting values: 11%
# Correcting values: 12%
# Correcting values: 13%
# Correcting values: 14%
# Correcting values: 15%
# Correcting values: 16%
# Correcting values: 17%
# Correcting values: 18%
# Correcting values: 19%
# Correcting values: 20%
# Correcting values: 21%
# Correcting values: 22%
# Correcting values: 23%
# Correcting values: 24%
# Correcting values: 25%
# Correcting values: 26%
# Correcting values: 27%
# Correcting values: 28%
# Correcting values: 29%
# Correcting values: 30%
# Correcting values: 31%
# Correcting values: 32%
# Correcting values: 33%
# Correcting values: 34%
# Correcting values: 35%
# Correcting values: 36%
# Correcting values: 37%
# Correcting values: 38%
# Correcting values: 39%
# Correcting values: 40%
# Correcting values: 41%
# Correcting values: 42%
# Correcting values: 43%
# Correcting values: 44%
# Correcting values: 45%
# Correcting values: 46%
# Correcting values: 47%
# Correcting values: 48%
# Correcting values: 49%
# Correcting values: 50%
# Correcting values: 51%
# Correcting values: 52%
# Correcting values: 53%
# Correcting values: 54%
# Correcting values: 55%
# Correcting values: 56%
# Correcting values: 57%
# Correcting values: 58%
# Correcting values: 59%
# Correcting values: 60%
# Correcting values: 61%
# Correcting values: 62%
# Correcting values: 63%
# Correcting values: 64%
# Correcting values: 65%
# Correcting values: 66%
# Correcting values: 67%
# Correcting values: 68%
# Correcting values: 69%
# Correcting values: 70%
# Correcting values: 71%
# Correcting values: 72%
# Correcting values: 73%
# Correcting values: 74%
# Correcting values: 75%
# Correcting values: 76%
# Correcting values: 77%
# Correcting values: 78%
# Correcting values: 79%
# Correcting values: 80%
# Correcting values: 81%
# Correcting values: 82%
# Correcting values: 83%
# Correcting values: 84%
# Correcting values: 85%
# Correcting values: 86%
# Correcting values: 87%
# Correcting values: 88%
# Correcting values: 89%
# Correcting values: 90%
# Correcting values: 91%
# Correcting values: 92%
# Correcting values: 93%
# Correcting values: 94%
# Correcting values: 95%
# Correcting values: 96%
# Correcting values: 97%
# Correcting values: 98%
# Correcting values: 99%
# Correcting values: 100%
# Saving flow pointer data...
# Output file written
# Saving accumulation data...
# Output file written
# Elapsed Time (excluding I/O): 14.633s
# .\whitebox_tools.exe --run="ExtractStreams" --flow_accum='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FA.tif' --output='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\STREAM.tif' --threshold='1000' -v --compress_rasters=False
#
# *****************************
# * Welcome to ExtractStreams *
# * Powered by WhiteboxTools  *
# * www.whiteboxgeo.com       *
# *****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.185s
# .\whitebox_tools.exe --run="RasterStreamsToVector" --streams='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\STREAM.tif' --d8_pntr='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FP.tif' --output='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\drainage_network.shp' -v --compress_rasters=False
#
# ************************************
# * Welcome to RasterStreamsToVector *
# * Powered by WhiteboxTools         *
# * www.whiteboxgeo.com              *
# ************************************
# Reading pointer data...
# Reading streams data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.241s
# 0

# %%
# Load GWT model and heads 
sim = flopy.mf6.MFSimulation.load(sim_name=modelName, sim_ws=model_path) 
gwf = sim.get_model()
head = gwf.output.head().get_data(kstpkper=(0, 0))
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package dis...
#     loading package ic...
#     loading package npf...
#     loading package obs...
#     loading package oc...
#     loading package chd...
#     loading package wel...
#     loading package riv...
# INFORMATION: maxbound in ('gwf6', 'riv', 'dimensions') changed to 18821 based on size of stress_period_data
#     loading package drn...
#     loading package rch...
#     loading package hfb...
#   loading solution package modflow...

# %%
#Get shape with all domain cells
# Get the idomain from the DIS package
idomain = gwf.dis.idomain.array  # Array 3D (layers, rows, columns)

# Extract active cells from the first layer (index 0)
layer = 0
rows, cols = np.where(idomain[layer] == 1)  # rows and columns activas

# Generar polígonos para cada celda activa
polygons = []
for row, col in zip(rows, cols):
    cell_vertices = gwf.modelgrid.get_cell_vertices(row, col)  # Get the vertices
    polygons.append(Polygon(cell_vertices))

# Create GeoDataFrame
gdf_domain = gpd.GeoDataFrame(geometry=polygons)
gdf_domain.crs = epgs  # Correct SRC

# %%
#Create folder to save files in the future
carpeta=os.path.join(calib_manan_path,calib_man)
os.makedirs(carpeta, exist_ok=True)
# Extract results of DRN package, for the steady state (layer, row, column, elev, cond)
drn_package = gwf.get_package("drn") 
drn_data = drn_package.stress_period_data.get_data()[0]
# CBC results
cbc = gwf.output.budget()
drn_cbc = cbc.get_data(text="DRN", kstpkper=(0, 0))[0]
# Diccionary for unique cells (row, col)
celdas_unicas = defaultdict(list)
# Group by row and column (without layer)
for cell in drn_data:
    cellid, elev_drn, cond, aux1, aux2, comment = cell  
    layer, row, col = cellid  
    celdas_unicas[(row, col)].append((layer, elev_drn))
# Create lists
polygons = []
elevaciones_drn = []
# Process each unique cell
for (row, col), valores in celdas_unicas.items():
    # Obtain the average elevation (or take the first one)
    elev_promedio = np.mean([v[1] for v in valores])
    
    # Get vertices of the cell
    cell_vertices = gwf.modelgrid.get_cell_vertices(row, col)
    polygon = Polygon(cell_vertices)
        
    polygons.append(polygon)
    elevaciones_drn.append(elev_promedio)
# Create GeoDataFrame
gdf_drn0 = gpd.GeoDataFrame(geometry=polygons,data={"elev_drn": elevaciones_drn})
gdf_drn0.crs = epgs 
# Now see the active cells in DRN package
celdas_agrupadas = defaultdict(list)
# Group DRN and CBC dates by cells, ignore layer
for cell, cbc_cell in zip(drn_data, drn_cbc):
    cellid, elev, cond, aux1, aux2, comment = cell
    layer, row, col = cellid
    q = cbc_cell["q"]
    
    # Save all values per cell (row, col)
    celdas_agrupadas[(row, col)].append({
        "layer": layer,
        "elev": elev,
        "q": q })                           
# Process each unique cell
polygons, elevaciones_drn, activos, cellids = [], [], [], []
for (row, col), valores in celdas_agrupadas.items():
    # Get cell geometry
    vertices = gwf.modelgrid.get_cell_vertices(row, col)
    polygon = Polygon(vertices)
    
    # Calculate values
    elev_promedio = np.mean([v["elev"] for v in valores])
    
    # Determine if it is active (if AT LEAST ONE input has q < 0)
    activo = any(v["q"] < 0 for v in valores)
        
    #Save Cellid
    cellid=(valores[0]["layer"], row, col)
    
    polygons.append(polygon)
    elevaciones_drn.append(elev_promedio)
    activos.append(activo) 
    cellids.append(cellid)
# Create GeoDataFrame
gdf_drn = gpd.GeoDataFrame(
    geometry=polygons,
    data={
        "elev_drn": elevaciones_drn,
        "activo": activos,
        "n_capas": [len(valores) for (row, col), valores in celdas_agrupadas.items()], 
        "cellid":cellids},
    crs="EPSG:32719")
gdf_drn_activas = gdf_drn[gdf_drn["activo"]].copy()

# %%
###If you already run this next cells once time, JUST RUN the next and the follow cell.

# %%
#Define some Functions:

#To extract vertices
def extract_specific_vertices(gdf, indices=[0, -1]):
    """
    Extract specific vertices from the geometries of a GeoDataFrame.
    
    Parameters:
    - gdf: GeoDataFrame with LineString or MultiLineString geometries.
    - indices: List of indices of vertices to extract (e.g., [0, -1] for first and last).
    
    Returns:
    - GeoDataFrame with points representing the selected vertices.
    """
    points = []
    attrs = []
    
    for idx, row in gdf.iterrows():
        geom = row.geometry
        
        if geom.geom_type == 'LineString':
            coords = list(geom.coords)
            for i in indices:
                if -len(coords) <= i < len(coords):
                    point = Point(coords[i])
                    points.append(point)
                    attrs.append({**row.to_dict(), 'vertex_index': i})
        
        elif geom.geom_type == 'MultiLineString':
            for line in geom.geoms:
                coords = list(line.coords)
                for i in indices:
                    if -len(coords) <= i < len(coords):
                        point = Point(coords[i])
                        points.append(point)
                        attrs.append({**row.to_dict(), 'vertex_index': i})
    
    return gpd.GeoDataFrame(attrs, geometry=points, crs=gdf.crs)

#To find the intersection between two lines
def find_line_intersections(gdf1, gdf2, crs=None):
    """
    Find intersection points between two layers of lines.
    
    Parameters:
    - gdf1, gdf2: GeoDataFrames with LineString/MultiLineString geometries.
    - crs: Coordinate reference system (if not defined).
    
    Returns:
    - GeoDataFrame with intersection points and attributes from both lines.
    """
    if crs is None:
        crs = gdf1.crs
    gdf1 = gdf1.to_crs(crs)
    gdf2 = gdf2.to_crs(crs)
    
    spatial_index = gdf2.sindex
    
    intersecciones = []
    for idx1, linea1 in gdf1.iterrows():
        # Finding candidates using the spatial index
        posibles_matches = list(spatial_index.intersection(linea1.geometry.bounds))
        for idx2 in posibles_matches:
            linea2 = gdf2.iloc[idx2]
            # Calculate intersection
            intersect = linea1.geometry.intersection(linea2.geometry)
            if not intersect.is_empty:
                # Managing MultiPoint and Point
                if intersect.geom_type == "MultiPoint":
                    puntos = list(intersect.geoms)
                else:
                    puntos = [intersect]
                # Save attributes for both lines
                for punto in puntos:
                    datos = {
                        **{f"gdf1_{k}": v for k, v in linea1.items()},
                        **{f"gdf2_{k}": v for k, v in linea2.items()},
                        "geometry": punto
                    }
                    intersecciones.append(datos)
    
    return gpd.GeoDataFrame(intersecciones, crs=crs)
    
#To see if they are equal points
def son_puntos_iguales(gdf1, gdf2):
    """
    Compare two GeoDataFrames of point geometries based on their coordinates.
    
    Parameters:
    - gdf1: A GeoDataFrame containing Point geometries.
    - gdf2: A GeoDataFrame containing Point geometries.
    
    Returns:
    - A boolean value indicating whether both GeoDataFrames contain exactly the
      same set of point coordinates.
    """
    coords1 = set((p.x, p.y) for p in gdf1.geometry)
    coords2 = set((p.x, p.y) for p in gdf2.geometry)
    return coords1 == coords2

#To find the difference between vectors
def vector_difference(input_gdf, overlay_gdf):
    """
    Calculates the geometric difference between two vector layers.
    
    Parameters:
    - input_gdf: GeoDataFrame with geometries to which the difference will be applied.
    - overlay_gdf: GeoDataFrame with geometries that will be subtracted from `input_gdf`.
    
    Returns:
    - GeoDataFrame with the parts of `input_gdf` that do not intersect with `overlay_gdf`.
    """
    # Ensure same CRS
    input_gdf = input_gdf.to_crs(overlay_gdf.crs)
    
    # Make a spatial difference
    diferencia = gpd.overlay(
        input_gdf,
        overlay_gdf,
        how='difference',
        keep_geom_type=True 
    )
    return diferencia

#To find the first element downstream
def encontrar_primer_elemento(punto, drenaje, target_layer, grafo_abajo):
    """
    Find the first feature in a target layer encountered when traversing a drainage
    network downstream from a given point.
    
    Parameters:
    - punto: A GeoSeries or GeoDataFrame row containing a Point geometry that defines
      the starting location.
    - drenaje: A GeoDataFrame representing the drainage network, where each row
      corresponds to a line segment.
    - target_layer: A GeoDataFrame containing geometries to be searched for
      intersection with the drainage network.
    - grafo_abajo: A dictionary or mapping structure that defines downstream
      connectivity between drainage segments, where keys are segment indices and
      values are lists of downstream segment indices.
    
    Returns:
    - The first row (as a GeoSeries) from the target_layer that intersects any
      drainage segment encountered during the downstream traversal.
    - Returns None if no intersecting element is found.
    """
    #Find initial segment
    distancias = drenaje.geometry.distance(punto.geometry)
    idx_segmento = distancias.idxmin()
    
    # Downstream search
    segmentos_visitados = set()
    cola = [idx_segmento]
    
    while cola:
        idx_actual = cola.pop(0)
        if idx_actual in segmentos_visitados:
            continue
        segmentos_visitados.add(idx_actual)
        
        segmento = drenaje.loc[idx_actual]
        
        # Buscar intersección con target_layer
        interseccion = target_layer[target_layer.intersects(segmento.geometry)]
        if not interseccion.empty:
            return interseccion.iloc[0]  # First item found
        
        cola.extend(grafo_abajo[idx_actual])
    
    return None

drenaje_global = None
poligonos_global = None
buffer_manan_global = None
grafo_abajo_global = None

def procesar_punto(idx_punto):
    """
    Process a single point by locating the first downstream intersecting features
    in two reference layers, extracting selected attributes, and (when possible)
    retrieving a hydraulic head value using a cell identifier.
    
    Parameters:
    - idx_punto: An index value used to select one row from the global GeoDataFrame
      'puntos'.
    
    Returns:
    - A dictionary with the following keys:
        - 'id_punto': An identifier for the point (as coded, this uses the variable
          'idx'; see Notes).
        - 'name': The 'name' attribute from the first downstream intersecting feature
          found in 'buffer_manan_global', or None if not found.
        - 'elev_manan': The 'elev_manan' attribute from the same feature, or None if
          not found.
        - 'elev_drn': A head value extracted from the global array 'head' using a
          (layer, row, col) tuple derived from 'cellid', or None if not obtained.
        - 'dif': The difference elev_drn - elev_manan when both values are available,
          otherwise None.
        - 'geometry': The geometry of the selected point.
    """
    punto = puntos.loc[idx_punto]
    celda_drn = encontrar_primer_elemento(punto, drenaje_global, poligonos_global, grafo_abajo_global)
    buffer = encontrar_primer_elemento(punto, drenaje_global, buffer_manan_global, grafo_abajo_global)
    if buffer is not None:
        name = buffer["name"]
        elev_manan = buffer["elev_manan"]
    else:
        name = None
        elev_manan = None
    elev_drn = None
    # Obtain hydraulic load from cellid
    if celda_drn is not None and "cellid" in celda_drn:
        cellid_raw = celda_drn["cellid"]

        if isinstance(cellid_raw, str):
            import ast
            try:
                cellid = ast.literal_eval(cellid_raw)
            except Exception as e:
                print(f"Error al convertir cellid: {cellid_raw}")
                cellid = None
        else:
            cellid = cellid_raw

        if isinstance(cellid, tuple) and len(cellid) == 3:
            layer, row, col = cellid
            try:
                elev_drn = head[layer, row, col]
            except IndexError:
                print(f"indice fuera de rango: {cellid}")
        else:
            print(f"cellid mal formado: {cellid_raw}")
    else:
        print(f"celda_drn invalido para idx {idx_punto}")
    dif = elev_drn - elev_manan if (elev_manan is not None and elev_drn is not None) else None
    return {
        "id_punto": idx,
        "name": name,
        "elev_manan": elev_manan,
        "elev_drn": elev_drn,
        "dif": dif,
        "geometry": punto.geometry}

# %%
buf_manan=os.path.join(carpeta, 'buf_manan.shp') #spring buffer for geospatial analysis
puntos_finales_red=os.path.join(carpeta, 'puntos_finales_red.shp') #end points in drainage network from each spring
stream_manan_final_inters=os.path.join(carpeta, 'stream_manan_final_inters.shp') # drainage cut off

# %%
#Define Output

snapped_points = carpeta+'/Man_ajust.shp'#Springs connected to the drainage network
flow_paths = carpeta+'/ruta_flujo.tif' #is a tif of drainage from the adjusted springs
flow_paths_lines = carpeta+'/ruta_flujo_lines.shp' # drainage polyline from adjusted springs
Drn_celdas_total= gdf_domain # polygon of cells used for drainage in the domain, change every time of you change the cell size
Drn_celdas_activas= gdf_drn_activas # polygon with active cells
puntos_final_v1=carpeta+'/ptos_linea_fin1.shp'  #points at the end of the drainage network created from tif
manan_filt_dom= carpeta+'/manan_filt_dom.shp' #springs adjusted to this new drainage system
snap_point_temp=carpeta+'/snap_point_temp.shp' # temporary point snaps
manan_filt_dom_2=carpeta+'/manan_filt_dom_2.shp' #springs that actually work in this dataset of springs
buf_manan=carpeta+'/buf_manan.shp' #spring buffer for geospatial analysis
puntos_finales_red=carpeta+'/puntos_finales_red.shp' #end points in drainage network  from each spring
flow_paths_2 = carpeta+'/ruta_flujo_2.tif' #is a tif of the drainage from the end points
stream_manan_final=carpeta+'/stream_manan_final.shp' #drainage from endpoints in shape
stream_manan_final_inters=carpeta+'/stream_manan_final_inters.shp'  # drainage cut off
resultados_final=carpeta+'/resultados_final.shp' # shape with points at the end of the drains with information on active drains that touch with their piezometry and spring elevation
resultados_filtrados=carpeta+'/resultados/resultados_filtrados.shp' # filtered final

# %%
#Use Saga to connect occupied springs to stream polyline
saga = SAGA(r"C:\Program Files\SAGA\saga_cmd.exe")
# Choose library
preprocessor = saga / 'shapes_points'
# Choose the tool
Snap_point_lines = preprocessor / 'Snap Points to Lines'
Snp=Snap_point_lines.execute(input=original_points,snap=drainage_network,output=snapped_points )

# %%
#Create raster and polyline streams from springs
wbt = whitebox.WhiteboxTools()
wbt.set_verbose_mode(True)
output_flow = flow_paths
wbt.trace_downslope_flowpaths(snapped_points, FP,output=flow_paths)  
wbt.raster_streams_to_vector(flow_paths,FP,output=flow_paths_lines) 
fpl = gpd.read_file(flow_paths_lines)
fpl=fpl.set_crs("EPSG:32719") #Just to confirm
fpl.to_file(flow_paths_lines)
# Out:
# .\whitebox_tools.exe --run="TraceDownslopeFlowpaths" --seed_pts='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/Man_ajust.shp' --d8_pntr='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FP.tif' --output='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/ruta_flujo.tif' -v --compress_rasters=False
#
# **************************************
# * Welcome to TraceDownslopeFlowpaths *
# * Powered by WhiteboxTools           *
# * www.whiteboxgeo.com                *
# **************************************
# Reading flow direction data...
# Locating seed points: 0%
# Locating seed points: 1%
# Locating seed points: 2%
# Locating seed points: 3%
# Locating seed points: 4%
# Locating seed points: 5%
# Locating seed points: 6%
# Locating seed points: 7%
# Locating seed points: 8%
# Locating seed points: 9%
# Locating seed points: 10%
# Locating seed points: 11%
# Locating seed points: 12%
# Locating seed points: 13%
# Locating seed points: 14%
# Locating seed points: 15%
# Locating seed points: 16%
# Locating seed points: 17%
# Locating seed points: 18%
# Locating seed points: 19%
# Locating seed points: 20%
# Locating seed points: 21%
# Locating seed points: 22%
# Locating seed points: 23%
# Locating seed points: 24%
# Locating seed points: 25%
# Locating seed points: 26%
# Locating seed points: 27%
# Locating seed points: 28%
# Locating seed points: 29%
# Locating seed points: 30%
# Locating seed points: 31%
# Locating seed points: 32%
# Locating seed points: 33%
# Locating seed points: 34%
# Locating seed points: 35%
# Locating seed points: 36%
# Locating seed points: 37%
# Locating seed points: 38%
# Locating seed points: 39%
# Locating seed points: 40%
# Locating seed points: 41%
# Locating seed points: 42%
# Locating seed points: 43%
# Locating seed points: 44%
# Locating seed points: 45%
# Locating seed points: 46%
# Locating seed points: 47%
# Locating seed points: 48%
# Locating seed points: 49%
# Locating seed points: 50%
# Locating seed points: 51%
# Locating seed points: 52%
# Locating seed points: 53%
# Locating seed points: 54%
# Locating seed points: 55%
# Locating seed points: 56%
# Locating seed points: 57%
# Locating seed points: 58%
# Locating seed points: 59%
# Locating seed points: 60%
# Locating seed points: 61%
# Locating seed points: 62%
# Locating seed points: 63%
# Locating seed points: 64%
# Locating seed points: 65%
# Locating seed points: 66%
# Locating seed points: 67%
# Locating seed points: 68%
# Locating seed points: 69%
# Locating seed points: 70%
# Locating seed points: 71%
# Locating seed points: 72%
# Locating seed points: 73%
# Locating seed points: 74%
# Locating seed points: 75%
# Locating seed points: 76%
# Locating seed points: 77%
# Locating seed points: 78%
# Locating seed points: 79%
# Locating seed points: 80%
# Locating seed points: 81%
# Locating seed points: 82%
# Locating seed points: 83%
# Locating seed points: 84%
# Locating seed points: 85%
# Locating seed points: 86%
# Locating seed points: 87%
# Locating seed points: 88%
# Locating seed points: 89%
# Locating seed points: 90%
# Locating seed points: 91%
# Locating seed points: 92%
# Locating seed points: 93%
# Locating seed points: 94%
# Locating seed points: 95%
# Locating seed points: 96%
# Locating seed points: 97%
# Locating seed points: 98%
# Locating seed points: 99%
# Locating seed points: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.253s
# .\whitebox_tools.exe --run="RasterStreamsToVector" --streams='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/ruta_flujo.tif' --d8_pntr='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FP.tif' --output='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/ruta_flujo_lines.shp' -v --compress_rasters=False
#
# ************************************
# * Welcome to RasterStreamsToVector *
# * Powered by WhiteboxTools         *
# * www.whiteboxgeo.com              *
# ************************************
# Reading pointer data...
# Reading streams data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.142s

# %%
# Load the previous polyline file
gdf = gpd.read_file(flow_paths_lines)
#Define formula for extract endpoints
def extraer_puntos_finales(geom):
    """
    Extract the start and end points from a LineString or MultiLineString geometry.
    
    Parameters:
    - geom: A Shapely geometry of type LineString or MultiLineString.
    
    Returns:
    - A list of Point geometries corresponding to the first and last coordinate
      of each LineString contained in the input geometry.
    """
    puntos = []
    if geom.geom_type == 'MultiLineString':
        for linea in geom.geoms:
            if len(linea.coords) >= 2:
                puntos.extend([Point(linea.coords[0]), Point(linea.coords[-1])])
    elif geom.geom_type == 'LineString':
        if len(geom.coords) >= 2:
            puntos.extend([Point(geom.coords[0]), Point(geom.coords[-1])])
    return puntos

# Step 1: Extract all endpoints
puntos_finales = []
for idx, fila in gdf.iterrows():
    puntos = extraer_puntos_finales(fila.geometry)
    for punto in puntos:
        puntos_finales.append({
            'id_linea': idx,
            'tipo_punto': 'inicio' if punto.equals(puntos[0]) else 'fin',
            'geometry': punto
        })

# Step 2: Identify intersection points (which appear on more than one line)
precision = 3  # Adjust according to coordinate system (e.g., 3 decimal places for UTM)
contador_puntos = defaultdict(int)

for p in puntos_finales:
    coord = (round(p['geometry'].x, precision), 
             round(p['geometry'].y, precision))
    contador_puntos[coord] += 1

# Step 3: Filter unique points (no intersections)
puntos_filtrados = [
    p for p in puntos_finales 
    if contador_puntos[(round(p['geometry'].x, precision), 
                       round(p['geometry'].y, precision))] == 1
]

# Create and save the result
gdf_puntos_filtrados = gpd.GeoDataFrame(puntos_filtrados, crs=gdf.crs)
gdf_puntos_filtrados.to_file(puntos_final_v1) 

#Load data
puntos = gpd.read_file(puntos_final_v1)
dominio=gpd.read_file(dom)

#Filter those within the domain to eliminate the lowest points
puntos_dentro = gpd.sjoin(
    puntos,
    dominio,
    how="inner",
    predicate="within"
).drop_duplicates(subset=['geometry'])
puntos_dentro.to_file(manan_filt_dom)

capa_entrada_0 = gpd.read_file(manan_filt_dom)  # Filter layer

#Create a buffer to intersect manan_filt_dom and extract the value of the “name” from the column 
#(but first create a point-to-point snap so that the points actually overlap due to position differences)
Snap_point_point = preprocessor / 'Snap Points to Points'
Snap_point_point.execute(input=snapped_points,snap=manan_filt_dom,output=snap_point_temp, distance=20) #20 because the snapped points we use come from a raster where the largest vector at the center of the rectangle does not exceed 20 m.
capa_dato=gpd.read_file(snap_point_temp)
capa_dato.geometry = capa_dato.geometry.buffer(1)
capa_dato=capa_dato.set_crs(dominio.crs)
puntos_unidos = gpd.sjoin(
    capa_entrada_0,
    capa_dato[["name","altitude", "geometry"]],  # Select the column to extract + geometry
    how="left",  
    predicate="intersects", 
    lsuffix="_orig",
    rsuffix="_datos"
)

# clean columns
puntos_unidos = puntos_unidos.drop(columns=['index_datos'], errors='ignore')
puntos_unidos=puntos_unidos.drop_duplicates(subset="id_linea", keep="first")
puntos_unidos = puntos_unidos.rename(columns={"altitude": "elev_manan"})
capa_entrada=puntos_unidos.drop(columns=["tipo_punto","id","id_linea"])

# Prepare reference layer
capa_referencia = Drn_celdas_total  # reference file
capa_referencia = capa_referencia.drop(columns=['index_right', 'index_left'], errors='ignore')

resultado = gpd.sjoin(capa_entrada, capa_referencia,  predicate="intersects")
resultado=resultado.rename(columns={'elev_drn':'elev_manan'})
resultado=resultado.drop(columns=["index_righ"])
resultado.to_file(manan_filt_dom_2)
buf = resultado.copy()
buf.geometry = buf.geometry.buffer(2)
buf=buf.set_crs(dominio.crs)
buf.to_file(buf_manan)
# Out:
# C:\Users\nick_\AppData\Local\Temp\ipykernel_8736\3080130842.py:67: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   puntos_dentro.to_file(manan_filt_dom)
# C:\Users\nick_\anaconda3\Lib\site-packages\pyogrio\raw.py:198: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D Point' is converted to 'Point Z'
#   return ogr_read(
# C:\Users\nick_\AppData\Local\Temp\ipykernel_8736\3080130842.py:100: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   resultado.to_file(manan_filt_dom_2)
# C:\Users\nick_\AppData\Local\Temp\ipykernel_8736\3080130842.py:104: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   buf.to_file(buf_manan)

# %%
#Extract drainage start points

t0 = time.time()
wbt = whitebox.WhiteboxTools()
wbt.work_dir = carpeta

# 1. Load initial data
stream_net_real = gpd.read_file(drainage_network)
manan_filt = gpd.read_file(manan_filt_dom_2)
stream_for_manan = gpd.read_file(flow_paths_lines)

if stream_for_manan.crs is None:
    stream_for_manan = stream_for_manan.set_crs(epgs)
if manan_filt.crs is None:
    manan_filt = manan_filt.set_crs(epgs)
if stream_net_real.crs is None:
    stream_net_real = stream_net_real.set_crs(epgs)

stream_for_manan.to_file(carpeta+'/temp_union_-1.shp')

# 2. Prepare the spatial index
sindex = stream_net_real.sindex

max_iteraciones = 20
tolerancia = 0.1
union_prev = None
vertices_prev = None

for i in range(max_iteraciones):
    print(f"\n--- Iteration {i+1} ---")
    
    # A. 1 m buffer with vectorized operation
    manan_filt["buffer"] = manan_filt.geometry.buffer(1.0)
    buf1 = gpd.GeoDataFrame(geometry=manan_filt["buffer"], crs=manan_filt.crs)
    buffer_union = buf1.geometry.union_all()

    # B. Optimized spatial selection with index
    # Just search for streams that may intersect with any buffer using the spatial index.
    possible_matches_index = list(sindex.intersection(buffer_union.bounds))
    possible_matches = stream_net_real.iloc[possible_matches_index]
    selec = possible_matches[possible_matches.intersects(buffer_union)]

    # C. Perform a WhiteboxTools union operation using temporary files on disk
    temp_union = f"temp_union_{i}.shp"
    if selec.crs is None:
        selec = selec.set_crs(epgs)
    selec.to_file(carpeta+f'/temp_selec_{i}.shp')
    selec_path = f"temp_selec_{i}.shp"
    prev_union_path = f"temp_union_{i-1}.shp" if i > 0 else carpeta+'/temp_union_-1.shp'
    wbt.union(prev_union_path, selec_path, temp_union)
    
    # D. Extract vertices and calculate intersections
    selec_temp = gpd.read_file(carpeta+f'/temp_selec_{i}.shp')
    if selec_temp.crs is None:
        selec_temp = selec_temp.set_crs(epgs)    
    nuevos_vertices = extract_specific_vertices(selec_temp, indices=[0])
    
    nuevas_intersecciones = find_line_intersections(selec_temp, selec_temp)
    nuevas_intersecciones = nuevas_intersecciones[nuevas_intersecciones.geometry.type.isin(["Point", "MultiPoint"])].explode(index_parts=True)
    nuevas_intersecciones["buffer"] = nuevas_intersecciones.geometry.buffer(1.0)
    buf2 = gpd.GeoDataFrame(geometry=nuevas_intersecciones["buffer"], crs=manan_filt.crs)
    dif = vector_difference(nuevos_vertices, buf2)
    nuevos_vertices = dif

    # F. Stop condition
    if i > 0 and son_puntos_iguales(nuevos_vertices, vertices_prev):
        print("Identical points! Stopping loop.")
        break
        
    # G. Update for the next iteration
    vertices_prev = nuevos_vertices.copy()
    manan_filt = nuevos_vertices

nuevos_vertices.to_file(puntos_finales_red)

print(f"\n---Optimized process completed  ---\nTook {time.time() - t0:.2f} seconds")
# Out:
# --- Iteration 1 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/temp_union_-1.shp' --overlay='temp_selec_0.shp' --output='temp_union_0.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (0): 0%
# Finding duplicate polylines (1): 1%
# Finding duplicate polylines (5): 2%
# Finding duplicate polylines (7): 3%
# Finding duplicate polylines (13): 4%
# Finding duplicate polylines (21): 5%
# Finding duplicate polylines (25): 6%
# Finding duplicate polylines (30): 7%
# Finding duplicate polylines (34): 8%
# Finding duplicate polylines (39): 9%
# Finding duplicate polylines (41): 10%
# Finding duplicate polylines (45): 11%
# Finding duplicate polylines (49): 12%
# Finding duplicate polylines (52): 13%
# Finding duplicate polylines (54): 14%
# Finding duplicate polylines (59): 15%
# Finding duplicate polylines (60): 16%
# Finding duplicate polylines (61): 17%
# Finding duplicate polylines (65): 18%
# Finding duplicate polylines (67): 19%
# Finding duplicate polylines (71): 20%
# Finding duplicate polylines (71): 21%
# Finding duplicate polylines (77): 22%
# Finding duplicate polylines (79): 23%
# Finding duplicate polylines (81): 24%
# Finding duplicate polylines (83): 25%
# Finding duplicate polylines (87): 26%
# Finding duplicate polylines (87): 27%
# Finding duplicate polylines (90): 28%
# Finding duplicate polylines (94): 29%
# Finding duplicate polylines (96): 30%
# Finding duplicate polylines (97): 31%
# Finding duplicate polylines (104): 32%
# Finding duplicate polylines (109): 33%
# Finding duplicate polylines (110): 34%
# Finding duplicate polylines (111): 35%
# Finding duplicate polylines (111): 36%
# Finding duplicate polylines (111): 37%
# Finding duplicate polylines (111): 38%
# Finding duplicate polylines (111): 39%
# Finding duplicate polylines (111): 40%
# Finding duplicate polylines (111): 41%
# Finding duplicate polylines (111): 42%
# Finding duplicate polylines (111): 43%
# Finding duplicate polylines (111): 44%
# Finding duplicate polylines (111): 45%
# Finding duplicate polylines (111): 46%
# Finding duplicate polylines (111): 47%
# Finding duplicate polylines (111): 48%
# Finding duplicate polylines (111): 49%
# Finding duplicate polylines (111): 50%
# Finding duplicate polylines (111): 51%
# Finding duplicate polylines (111): 52%
# Finding duplicate polylines (111): 53%
# Finding duplicate polylines (111): 54%
# Finding duplicate polylines (111): 55%
# Finding duplicate polylines (111): 56%
# Finding duplicate polylines (111): 57%
# Finding duplicate polylines (111): 58%
# Finding duplicate polylines (111): 59%
# Finding duplicate polylines (111): 60%
# Finding duplicate polylines (111): 61%
# Finding duplicate polylines (111): 62%
# Finding duplicate polylines (111): 63%
# Finding duplicate polylines (111): 64%
# Finding duplicate polylines (111): 65%
# Finding duplicate polylines (111): 66%
# Finding duplicate polylines (111): 67%
# Finding duplicate polylines (111): 68%
# Finding duplicate polylines (111): 69%
# Finding duplicate polylines (111): 70%
# Finding duplicate polylines (111): 71%
# Finding duplicate polylines (111): 72%
# Finding duplicate polylines (111): 73%
# Finding duplicate polylines (111): 74%
# Finding duplicate polylines (111): 75%
# Finding duplicate polylines (111): 76%
# Finding duplicate polylines (111): 77%
# Finding duplicate polylines (111): 78%
# Finding duplicate polylines (111): 79%
# Finding duplicate polylines (111): 80%
# Finding duplicate polylines (111): 81%
# Finding duplicate polylines (111): 82%
# Finding duplicate polylines (111): 83%
# Finding duplicate polylines (111): 84%
# Finding duplicate polylines (111): 85%
# Finding duplicate polylines (111): 86%
# Finding duplicate polylines (111): 87%
# Finding duplicate polylines (111): 88%
# Finding duplicate polylines (111): 89%
# Finding duplicate polylines (111): 90%
# Finding duplicate polylines (111): 91%
# Finding duplicate polylines (111): 92%
# Finding duplicate polylines (111): 93%
# Finding duplicate polylines (111): 94%
# Finding duplicate polylines (111): 95%
# Finding duplicate polylines (111): 96%
# Finding duplicate polylines (111): 97%
# Finding duplicate polylines (111): 98%
# Finding duplicate polylines (111): 99%
# Finding duplicate polylines (111): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.117s
#
# --- Iteration 2 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_0.shp' --overlay='temp_selec_1.shp' --output='temp_union_1.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (202): 1%
# Finding duplicate polylines (407): 2%
# Finding duplicate polylines (572): 3%
# Finding duplicate polylines (768): 4%
# Finding duplicate polylines (971): 5%
# Finding duplicate polylines (1171): 6%
# Finding duplicate polylines (1369): 7%
# Finding duplicate polylines (1571): 8%
# Finding duplicate polylines (1776): 9%
# Finding duplicate polylines (1983): 10%
# Finding duplicate polylines (2193): 11%
# Finding duplicate polylines (2390): 12%
# Finding duplicate polylines (2598): 13%
# Finding duplicate polylines (2802): 14%
# Finding duplicate polylines (3000): 15%
# Finding duplicate polylines (3200): 16%
# Finding duplicate polylines (3404): 17%
# Finding duplicate polylines (3605): 18%
# Finding duplicate polylines (3799): 19%
# Finding duplicate polylines (4006): 20%
# Finding duplicate polylines (4214): 21%
# Finding duplicate polylines (4424): 22%
# Finding duplicate polylines (4633): 23%
# Finding duplicate polylines (4839): 24%
# Finding duplicate polylines (5048): 25%
# Finding duplicate polylines (5242): 26%
# Finding duplicate polylines (5436): 27%
# Finding duplicate polylines (5642): 28%
# Finding duplicate polylines (5842): 29%
# Finding duplicate polylines (6041): 30%
# Finding duplicate polylines (6251): 31%
# Finding duplicate polylines (6453): 32%
# Finding duplicate polylines (6544): 33%
# Finding duplicate polylines (6544): 34%
# Finding duplicate polylines (6544): 35%
# Finding duplicate polylines (6544): 36%
# Finding duplicate polylines (6544): 37%
# Finding duplicate polylines (6544): 38%
# Finding duplicate polylines (6544): 39%
# Finding duplicate polylines (6544): 40%
# Finding duplicate polylines (6544): 41%
# Finding duplicate polylines (6544): 42%
# Finding duplicate polylines (6544): 43%
# Finding duplicate polylines (6544): 44%
# Finding duplicate polylines (6544): 45%
# Finding duplicate polylines (6544): 46%
# Finding duplicate polylines (6544): 47%
# Finding duplicate polylines (6544): 48%
# Finding duplicate polylines (6544): 49%
# Finding duplicate polylines (6544): 50%
# Finding duplicate polylines (6544): 51%
# Finding duplicate polylines (6544): 52%
# Finding duplicate polylines (6544): 53%
# Finding duplicate polylines (6544): 54%
# Finding duplicate polylines (6544): 55%
# Finding duplicate polylines (6544): 56%
# Finding duplicate polylines (6544): 57%
# Finding duplicate polylines (6544): 58%
# Finding duplicate polylines (6544): 59%
# Finding duplicate polylines (6544): 60%
# Finding duplicate polylines (6544): 61%
# Finding duplicate polylines (6544): 62%
# Finding duplicate polylines (6544): 63%
# Finding duplicate polylines (6544): 64%
# Finding duplicate polylines (6544): 65%
# Finding duplicate polylines (6544): 66%
# Finding duplicate polylines (6544): 67%
# Finding duplicate polylines (6544): 68%
# Finding duplicate polylines (6544): 69%
# Finding duplicate polylines (6544): 70%
# Finding duplicate polylines (6544): 71%
# Finding duplicate polylines (6544): 72%
# Finding duplicate polylines (6544): 73%
# Finding duplicate polylines (6544): 74%
# Finding duplicate polylines (6544): 75%
# Finding duplicate polylines (6544): 76%
# Finding duplicate polylines (6544): 77%
# Finding duplicate polylines (6544): 78%
# Finding duplicate polylines (6544): 79%
# Finding duplicate polylines (6544): 80%
# Finding duplicate polylines (6544): 81%
# Finding duplicate polylines (6544): 82%
# Finding duplicate polylines (6544): 83%
# Finding duplicate polylines (6544): 84%
# Finding duplicate polylines (6544): 85%
# Finding duplicate polylines (6544): 86%
# Finding duplicate polylines (6544): 87%
# Finding duplicate polylines (6544): 88%
# Finding duplicate polylines (6544): 89%
# Finding duplicate polylines (6544): 90%
# Finding duplicate polylines (6544): 91%
# Finding duplicate polylines (6544): 92%
# Finding duplicate polylines (6544): 93%
# Finding duplicate polylines (6544): 94%
# Finding duplicate polylines (6544): 95%
# Finding duplicate polylines (6544): 96%
# Finding duplicate polylines (6544): 97%
# Finding duplicate polylines (6544): 98%
# Finding duplicate polylines (6544): 99%
# Finding duplicate polylines (6544): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.110s
#
# --- Iteration 3 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_1.shp' --overlay='temp_selec_2.shp' --output='temp_union_2.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (203): 1%
# Finding duplicate polylines (403): 2%
# Finding duplicate polylines (568): 3%
# Finding duplicate polylines (773): 4%
# Finding duplicate polylines (974): 5%
# Finding duplicate polylines (1166): 6%
# Finding duplicate polylines (1374): 7%
# Finding duplicate polylines (1573): 8%
# Finding duplicate polylines (1781): 9%
# Finding duplicate polylines (1990): 10%
# Finding duplicate polylines (2194): 11%
# Finding duplicate polylines (2391): 12%
# Finding duplicate polylines (2599): 13%
# Finding duplicate polylines (2798): 14%
# Finding duplicate polylines (2999): 15%
# Finding duplicate polylines (3202): 16%
# Finding duplicate polylines (3404): 17%
# Finding duplicate polylines (3603): 18%
# Finding duplicate polylines (3808): 19%
# Finding duplicate polylines (4016): 20%
# Finding duplicate polylines (4226): 21%
# Finding duplicate polylines (4435): 22%
# Finding duplicate polylines (4643): 23%
# Finding duplicate polylines (4850): 24%
# Finding duplicate polylines (5047): 25%
# Finding duplicate polylines (5247): 26%
# Finding duplicate polylines (5453): 27%
# Finding duplicate polylines (5648): 28%
# Finding duplicate polylines (5854): 29%
# Finding duplicate polylines (6062): 30%
# Finding duplicate polylines (6264): 31%
# Finding duplicate polylines (6319): 32%
# Finding duplicate polylines (6319): 33%
# Finding duplicate polylines (6319): 34%
# Finding duplicate polylines (6319): 35%
# Finding duplicate polylines (6319): 36%
# Finding duplicate polylines (6319): 37%
# Finding duplicate polylines (6319): 38%
# Finding duplicate polylines (6319): 39%
# Finding duplicate polylines (6319): 40%
# Finding duplicate polylines (6319): 41%
# Finding duplicate polylines (6319): 42%
# Finding duplicate polylines (6319): 43%
# Finding duplicate polylines (6319): 44%
# Finding duplicate polylines (6319): 45%
# Finding duplicate polylines (6319): 46%
# Finding duplicate polylines (6319): 47%
# Finding duplicate polylines (6319): 48%
# Finding duplicate polylines (6319): 49%
# Finding duplicate polylines (6319): 50%
# Finding duplicate polylines (6319): 51%
# Finding duplicate polylines (6319): 52%
# Finding duplicate polylines (6319): 53%
# Finding duplicate polylines (6319): 54%
# Finding duplicate polylines (6319): 55%
# Finding duplicate polylines (6319): 56%
# Finding duplicate polylines (6319): 57%
# Finding duplicate polylines (6319): 58%
# Finding duplicate polylines (6319): 59%
# Finding duplicate polylines (6319): 60%
# Finding duplicate polylines (6319): 61%
# Finding duplicate polylines (6319): 62%
# Finding duplicate polylines (6319): 63%
# Finding duplicate polylines (6319): 64%
# Finding duplicate polylines (6319): 65%
# Finding duplicate polylines (6319): 66%
# Finding duplicate polylines (6319): 67%
# Finding duplicate polylines (6319): 68%
# Finding duplicate polylines (6319): 69%
# Finding duplicate polylines (6319): 70%
# Finding duplicate polylines (6319): 71%
# Finding duplicate polylines (6319): 72%
# Finding duplicate polylines (6319): 73%
# Finding duplicate polylines (6319): 74%
# Finding duplicate polylines (6319): 75%
# Finding duplicate polylines (6319): 76%
# Finding duplicate polylines (6319): 77%
# Finding duplicate polylines (6319): 78%
# Finding duplicate polylines (6319): 79%
# Finding duplicate polylines (6319): 80%
# Finding duplicate polylines (6319): 81%
# Finding duplicate polylines (6319): 82%
# Finding duplicate polylines (6319): 83%
# Finding duplicate polylines (6319): 84%
# Finding duplicate polylines (6319): 85%
# Finding duplicate polylines (6319): 86%
# Finding duplicate polylines (6319): 87%
# Finding duplicate polylines (6319): 88%
# Finding duplicate polylines (6319): 89%
# Finding duplicate polylines (6319): 90%
# Finding duplicate polylines (6319): 91%
# Finding duplicate polylines (6319): 92%
# Finding duplicate polylines (6319): 93%
# Finding duplicate polylines (6319): 94%
# Finding duplicate polylines (6319): 95%
# Finding duplicate polylines (6319): 96%
# Finding duplicate polylines (6319): 97%
# Finding duplicate polylines (6319): 98%
# Finding duplicate polylines (6319): 99%
# Finding duplicate polylines (6319): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.140s
#
# --- Iteration 4 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_2.shp' --overlay='temp_selec_3.shp' --output='temp_union_3.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (206): 1%
# Finding duplicate polylines (409): 2%
# Finding duplicate polylines (576): 3%
# Finding duplicate polylines (783): 4%
# Finding duplicate polylines (986): 5%
# Finding duplicate polylines (1181): 6%
# Finding duplicate polylines (1389): 7%
# Finding duplicate polylines (1592): 8%
# Finding duplicate polylines (1803): 9%
# Finding duplicate polylines (2016): 10%
# Finding duplicate polylines (2218): 11%
# Finding duplicate polylines (2416): 12%
# Finding duplicate polylines (2627): 13%
# Finding duplicate polylines (2828): 14%
# Finding duplicate polylines (3031): 15%
# Finding duplicate polylines (3236): 16%
# Finding duplicate polylines (3438): 17%
# Finding duplicate polylines (3638): 18%
# Finding duplicate polylines (3851): 19%
# Finding duplicate polylines (4061): 20%
# Finding duplicate polylines (4273): 21%
# Finding duplicate polylines (4484): 22%
# Finding duplicate polylines (4694): 23%
# Finding duplicate polylines (4905): 24%
# Finding duplicate polylines (5102): 25%
# Finding duplicate polylines (5306): 26%
# Finding duplicate polylines (5517): 27%
# Finding duplicate polylines (5716): 28%
# Finding duplicate polylines (5924): 29%
# Finding duplicate polylines (6134): 30%
# Finding duplicate polylines (6324): 31%
# Finding duplicate polylines (6324): 32%
# Finding duplicate polylines (6324): 33%
# Finding duplicate polylines (6324): 34%
# Finding duplicate polylines (6324): 35%
# Finding duplicate polylines (6324): 36%
# Finding duplicate polylines (6324): 37%
# Finding duplicate polylines (6324): 38%
# Finding duplicate polylines (6324): 39%
# Finding duplicate polylines (6324): 40%
# Finding duplicate polylines (6324): 41%
# Finding duplicate polylines (6324): 42%
# Finding duplicate polylines (6324): 43%
# Finding duplicate polylines (6324): 44%
# Finding duplicate polylines (6324): 45%
# Finding duplicate polylines (6324): 46%
# Finding duplicate polylines (6324): 47%
# Finding duplicate polylines (6324): 48%
# Finding duplicate polylines (6324): 49%
# Finding duplicate polylines (6324): 50%
# Finding duplicate polylines (6324): 51%
# Finding duplicate polylines (6324): 52%
# Finding duplicate polylines (6324): 53%
# Finding duplicate polylines (6324): 54%
# Finding duplicate polylines (6324): 55%
# Finding duplicate polylines (6324): 56%
# Finding duplicate polylines (6324): 57%
# Finding duplicate polylines (6324): 58%
# Finding duplicate polylines (6324): 59%
# Finding duplicate polylines (6324): 60%
# Finding duplicate polylines (6324): 61%
# Finding duplicate polylines (6324): 62%
# Finding duplicate polylines (6324): 63%
# Finding duplicate polylines (6324): 64%
# Finding duplicate polylines (6324): 65%
# Finding duplicate polylines (6324): 66%
# Finding duplicate polylines (6324): 67%
# Finding duplicate polylines (6324): 68%
# Finding duplicate polylines (6324): 69%
# Finding duplicate polylines (6324): 70%
# Finding duplicate polylines (6324): 71%
# Finding duplicate polylines (6324): 72%
# Finding duplicate polylines (6324): 73%
# Finding duplicate polylines (6324): 74%
# Finding duplicate polylines (6324): 75%
# Finding duplicate polylines (6324): 76%
# Finding duplicate polylines (6324): 77%
# Finding duplicate polylines (6324): 78%
# Finding duplicate polylines (6324): 79%
# Finding duplicate polylines (6324): 80%
# Finding duplicate polylines (6324): 81%
# Finding duplicate polylines (6324): 82%
# Finding duplicate polylines (6324): 83%
# Finding duplicate polylines (6324): 84%
# Finding duplicate polylines (6324): 85%
# Finding duplicate polylines (6324): 86%
# Finding duplicate polylines (6324): 87%
# Finding duplicate polylines (6324): 88%
# Finding duplicate polylines (6324): 89%
# Finding duplicate polylines (6324): 90%
# Finding duplicate polylines (6324): 91%
# Finding duplicate polylines (6324): 92%
# Finding duplicate polylines (6324): 93%
# Finding duplicate polylines (6324): 94%
# Finding duplicate polylines (6324): 95%
# Finding duplicate polylines (6324): 96%
# Finding duplicate polylines (6324): 97%
# Finding duplicate polylines (6324): 98%
# Finding duplicate polylines (6324): 99%
# Finding duplicate polylines (6324): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.197s
#
# --- Iteration 5 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_3.shp' --overlay='temp_selec_4.shp' --output='temp_union_4.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (208): 1%
# Finding duplicate polylines (413): 2%
# Finding duplicate polylines (584): 3%
# Finding duplicate polylines (793): 4%
# Finding duplicate polylines (998): 5%
# Finding duplicate polylines (1197): 6%
# Finding duplicate polylines (1407): 7%
# Finding duplicate polylines (1612): 8%
# Finding duplicate polylines (1827): 9%
# Finding duplicate polylines (2040): 10%
# Finding duplicate polylines (2239): 11%
# Finding duplicate polylines (2442): 12%
# Finding duplicate polylines (2656): 13%
# Finding duplicate polylines (2857): 14%
# Finding duplicate polylines (3066): 15%
# Finding duplicate polylines (3273): 16%
# Finding duplicate polylines (3479): 17%
# Finding duplicate polylines (3682): 18%
# Finding duplicate polylines (3894): 19%
# Finding duplicate polylines (4108): 20%
# Finding duplicate polylines (4324): 21%
# Finding duplicate polylines (4537): 22%
# Finding duplicate polylines (4751): 23%
# Finding duplicate polylines (4958): 24%
# Finding duplicate polylines (5159): 25%
# Finding duplicate polylines (5371): 26%
# Finding duplicate polylines (5578): 27%
# Finding duplicate polylines (5780): 28%
# Finding duplicate polylines (5996): 29%
# Finding duplicate polylines (6203): 30%
# Finding duplicate polylines (6330): 31%
# Finding duplicate polylines (6330): 32%
# Finding duplicate polylines (6330): 33%
# Finding duplicate polylines (6330): 34%
# Finding duplicate polylines (6330): 35%
# Finding duplicate polylines (6330): 36%
# Finding duplicate polylines (6330): 37%
# Finding duplicate polylines (6330): 38%
# Finding duplicate polylines (6330): 39%
# Finding duplicate polylines (6330): 40%
# Finding duplicate polylines (6330): 41%
# Finding duplicate polylines (6330): 42%
# Finding duplicate polylines (6330): 43%
# Finding duplicate polylines (6330): 44%
# Finding duplicate polylines (6330): 45%
# Finding duplicate polylines (6330): 46%
# Finding duplicate polylines (6330): 47%
# Finding duplicate polylines (6330): 48%
# Finding duplicate polylines (6330): 49%
# Finding duplicate polylines (6330): 50%
# Finding duplicate polylines (6330): 51%
# Finding duplicate polylines (6330): 52%
# Finding duplicate polylines (6330): 53%
# Finding duplicate polylines (6330): 54%
# Finding duplicate polylines (6330): 55%
# Finding duplicate polylines (6330): 56%
# Finding duplicate polylines (6330): 57%
# Finding duplicate polylines (6330): 58%
# Finding duplicate polylines (6330): 59%
# Finding duplicate polylines (6330): 60%
# Finding duplicate polylines (6330): 61%
# Finding duplicate polylines (6330): 62%
# Finding duplicate polylines (6330): 63%
# Finding duplicate polylines (6330): 64%
# Finding duplicate polylines (6330): 65%
# Finding duplicate polylines (6330): 66%
# Finding duplicate polylines (6330): 67%
# Finding duplicate polylines (6330): 68%
# Finding duplicate polylines (6330): 69%
# Finding duplicate polylines (6330): 70%
# Finding duplicate polylines (6330): 71%
# Finding duplicate polylines (6330): 72%
# Finding duplicate polylines (6330): 73%
# Finding duplicate polylines (6330): 74%
# Finding duplicate polylines (6330): 75%
# Finding duplicate polylines (6330): 76%
# Finding duplicate polylines (6330): 77%
# Finding duplicate polylines (6330): 78%
# Finding duplicate polylines (6330): 79%
# Finding duplicate polylines (6330): 80%
# Finding duplicate polylines (6330): 81%
# Finding duplicate polylines (6330): 82%
# Finding duplicate polylines (6330): 83%
# Finding duplicate polylines (6330): 84%
# Finding duplicate polylines (6330): 85%
# Finding duplicate polylines (6330): 86%
# Finding duplicate polylines (6330): 87%
# Finding duplicate polylines (6330): 88%
# Finding duplicate polylines (6330): 89%
# Finding duplicate polylines (6330): 90%
# Finding duplicate polylines (6330): 91%
# Finding duplicate polylines (6330): 92%
# Finding duplicate polylines (6330): 93%
# Finding duplicate polylines (6330): 94%
# Finding duplicate polylines (6330): 95%
# Finding duplicate polylines (6330): 96%
# Finding duplicate polylines (6330): 97%
# Finding duplicate polylines (6330): 98%
# Finding duplicate polylines (6330): 99%
# Finding duplicate polylines (6330): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.173s
#
# --- Iteration 6 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_4.shp' --overlay='temp_selec_5.shp' --output='temp_union_5.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (210): 1%
# Finding duplicate polylines (417): 2%
# Finding duplicate polylines (589): 3%
# Finding duplicate polylines (803): 4%
# Finding duplicate polylines (1010): 5%
# Finding duplicate polylines (1211): 6%
# Finding duplicate polylines (1425): 7%
# Finding duplicate polylines (1632): 8%
# Finding duplicate polylines (1849): 9%
# Finding duplicate polylines (2064): 10%
# Finding duplicate polylines (2263): 11%
# Finding duplicate polylines (2465): 12%
# Finding duplicate polylines (2681): 13%
# Finding duplicate polylines (2886): 14%
# Finding duplicate polylines (3092): 15%
# Finding duplicate polylines (3306): 16%
# Finding duplicate polylines (3516): 17%
# Finding duplicate polylines (3719): 18%
# Finding duplicate polylines (3935): 19%
# Finding duplicate polylines (4151): 20%
# Finding duplicate polylines (4369): 21%
# Finding duplicate polylines (4584): 22%
# Finding duplicate polylines (4799): 23%
# Finding duplicate polylines (5008): 24%
# Finding duplicate polylines (5214): 25%
# Finding duplicate polylines (5428): 26%
# Finding duplicate polylines (5634): 27%
# Finding duplicate polylines (5843): 28%
# Finding duplicate polylines (6061): 29%
# Finding duplicate polylines (6265): 30%
# Finding duplicate polylines (6334): 31%
# Finding duplicate polylines (6334): 32%
# Finding duplicate polylines (6334): 33%
# Finding duplicate polylines (6334): 34%
# Finding duplicate polylines (6334): 35%
# Finding duplicate polylines (6334): 36%
# Finding duplicate polylines (6334): 37%
# Finding duplicate polylines (6334): 38%
# Finding duplicate polylines (6334): 39%
# Finding duplicate polylines (6334): 40%
# Finding duplicate polylines (6334): 41%
# Finding duplicate polylines (6334): 42%
# Finding duplicate polylines (6334): 43%
# Finding duplicate polylines (6334): 44%
# Finding duplicate polylines (6334): 45%
# Finding duplicate polylines (6334): 46%
# Finding duplicate polylines (6334): 47%
# Finding duplicate polylines (6334): 48%
# Finding duplicate polylines (6334): 49%
# Finding duplicate polylines (6334): 50%
# Finding duplicate polylines (6334): 51%
# Finding duplicate polylines (6334): 52%
# Finding duplicate polylines (6334): 53%
# Finding duplicate polylines (6334): 54%
# Finding duplicate polylines (6334): 55%
# Finding duplicate polylines (6334): 56%
# Finding duplicate polylines (6334): 57%
# Finding duplicate polylines (6334): 58%
# Finding duplicate polylines (6334): 59%
# Finding duplicate polylines (6334): 60%
# Finding duplicate polylines (6334): 61%
# Finding duplicate polylines (6334): 62%
# Finding duplicate polylines (6334): 63%
# Finding duplicate polylines (6334): 64%
# Finding duplicate polylines (6334): 65%
# Finding duplicate polylines (6334): 66%
# Finding duplicate polylines (6334): 67%
# Finding duplicate polylines (6334): 68%
# Finding duplicate polylines (6334): 69%
# Finding duplicate polylines (6334): 70%
# Finding duplicate polylines (6334): 71%
# Finding duplicate polylines (6334): 72%
# Finding duplicate polylines (6334): 73%
# Finding duplicate polylines (6334): 74%
# Finding duplicate polylines (6334): 75%
# Finding duplicate polylines (6334): 76%
# Finding duplicate polylines (6334): 77%
# Finding duplicate polylines (6334): 78%
# Finding duplicate polylines (6334): 79%
# Finding duplicate polylines (6334): 80%
# Finding duplicate polylines (6334): 81%
# Finding duplicate polylines (6334): 82%
# Finding duplicate polylines (6334): 83%
# Finding duplicate polylines (6334): 84%
# Finding duplicate polylines (6334): 85%
# Finding duplicate polylines (6334): 86%
# Finding duplicate polylines (6334): 87%
# Finding duplicate polylines (6334): 88%
# Finding duplicate polylines (6334): 89%
# Finding duplicate polylines (6334): 90%
# Finding duplicate polylines (6334): 91%
# Finding duplicate polylines (6334): 92%
# Finding duplicate polylines (6334): 93%
# Finding duplicate polylines (6334): 94%
# Finding duplicate polylines (6334): 95%
# Finding duplicate polylines (6334): 96%
# Finding duplicate polylines (6334): 97%
# Finding duplicate polylines (6334): 98%
# Finding duplicate polylines (6334): 99%
# Finding duplicate polylines (6334): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.182s
#
# --- Iteration 7 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_5.shp' --overlay='temp_selec_6.shp' --output='temp_union_6.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (212): 1%
# Finding duplicate polylines (419): 2%
# Finding duplicate polylines (594): 3%
# Finding duplicate polylines (813): 4%
# Finding duplicate polylines (1022): 5%
# Finding duplicate polylines (1225): 6%
# Finding duplicate polylines (1440): 7%
# Finding duplicate polylines (1652): 8%
# Finding duplicate polylines (1871): 9%
# Finding duplicate polylines (2088): 10%
# Finding duplicate polylines (2293): 11%
# Finding duplicate polylines (2497): 12%
# Finding duplicate polylines (2715): 13%
# Finding duplicate polylines (2924): 14%
# Finding duplicate polylines (3132): 15%
# Finding duplicate polylines (3348): 16%
# Finding duplicate polylines (3560): 17%
# Finding duplicate polylines (3767): 18%
# Finding duplicate polylines (3985): 19%
# Finding duplicate polylines (4203): 20%
# Finding duplicate polylines (4422): 21%
# Finding duplicate polylines (4640): 22%
# ...
# Finding duplicate polylines (6381): 76%
# Finding duplicate polylines (6381): 77%
# Finding duplicate polylines (6381): 78%
# Finding duplicate polylines (6381): 79%
# Finding duplicate polylines (6381): 80%
# Finding duplicate polylines (6381): 81%
# Finding duplicate polylines (6381): 82%
# Finding duplicate polylines (6381): 83%
# Finding duplicate polylines (6381): 84%
# Finding duplicate polylines (6381): 85%
# Finding duplicate polylines (6381): 86%
# Finding duplicate polylines (6381): 87%
# Finding duplicate polylines (6381): 88%
# Finding duplicate polylines (6381): 89%
# Finding duplicate polylines (6381): 90%
# Finding duplicate polylines (6381): 91%
# Finding duplicate polylines (6381): 92%
# Finding duplicate polylines (6381): 93%
# Finding duplicate polylines (6381): 94%
# Finding duplicate polylines (6381): 95%
# Finding duplicate polylines (6381): 96%
# Finding duplicate polylines (6381): 97%
# Finding duplicate polylines (6381): 98%
# Finding duplicate polylines (6381): 99%
# Finding duplicate polylines (6381): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.197s
#
# --- Iteration 19 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_17.shp' --overlay='temp_selec_18.shp' --output='temp_union_18.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (236): 1%
# Finding duplicate polylines (450): 2%
# Finding duplicate polylines (671): 3%
# Finding duplicate polylines (909): 4%
# Finding duplicate polylines (1138): 5%
# Finding duplicate polylines (1380): 6%
# Finding duplicate polylines (1616): 7%
# Finding duplicate polylines (1861): 8%
# Finding duplicate polylines (2106): 9%
# Finding duplicate polylines (2324): 10%
# Finding duplicate polylines (2554): 11%
# Finding duplicate polylines (2795): 12%
# Finding duplicate polylines (3026): 13%
# Finding duplicate polylines (3240): 14%
# Finding duplicate polylines (3478): 15%
# Finding duplicate polylines (3711): 16%
# Finding duplicate polylines (3955): 17%
# Finding duplicate polylines (4201): 18%
# Finding duplicate polylines (4446): 19%
# Finding duplicate polylines (4690): 20%
# Finding duplicate polylines (4935): 21%
# Finding duplicate polylines (5167): 22%
# Finding duplicate polylines (5404): 23%
# Finding duplicate polylines (5640): 24%
# Finding duplicate polylines (5877): 25%
# Finding duplicate polylines (6122): 26%
# Finding duplicate polylines (6350): 27%
# Finding duplicate polylines (6383): 28%
# Finding duplicate polylines (6383): 29%
# Finding duplicate polylines (6383): 30%
# Finding duplicate polylines (6383): 31%
# Finding duplicate polylines (6383): 32%
# Finding duplicate polylines (6383): 33%
# Finding duplicate polylines (6383): 34%
# Finding duplicate polylines (6383): 35%
# Finding duplicate polylines (6383): 36%
# Finding duplicate polylines (6383): 37%
# Finding duplicate polylines (6383): 38%
# Finding duplicate polylines (6383): 39%
# Finding duplicate polylines (6383): 40%
# Finding duplicate polylines (6383): 41%
# Finding duplicate polylines (6383): 42%
# Finding duplicate polylines (6383): 43%
# Finding duplicate polylines (6383): 44%
# Finding duplicate polylines (6383): 45%
# Finding duplicate polylines (6383): 46%
# Finding duplicate polylines (6383): 47%
# Finding duplicate polylines (6383): 48%
# Finding duplicate polylines (6383): 49%
# Finding duplicate polylines (6383): 50%
# Finding duplicate polylines (6383): 51%
# Finding duplicate polylines (6383): 52%
# Finding duplicate polylines (6383): 53%
# Finding duplicate polylines (6383): 54%
# Finding duplicate polylines (6383): 55%
# Finding duplicate polylines (6383): 56%
# Finding duplicate polylines (6383): 57%
# Finding duplicate polylines (6383): 58%
# Finding duplicate polylines (6383): 59%
# Finding duplicate polylines (6383): 60%
# Finding duplicate polylines (6383): 61%
# Finding duplicate polylines (6383): 62%
# Finding duplicate polylines (6383): 63%
# Finding duplicate polylines (6383): 64%
# Finding duplicate polylines (6383): 65%
# Finding duplicate polylines (6383): 66%
# Finding duplicate polylines (6383): 67%
# Finding duplicate polylines (6383): 68%
# Finding duplicate polylines (6383): 69%
# Finding duplicate polylines (6383): 70%
# Finding duplicate polylines (6383): 71%
# Finding duplicate polylines (6383): 72%
# Finding duplicate polylines (6383): 73%
# Finding duplicate polylines (6383): 74%
# Finding duplicate polylines (6383): 75%
# Finding duplicate polylines (6383): 76%
# Finding duplicate polylines (6383): 77%
# Finding duplicate polylines (6383): 78%
# Finding duplicate polylines (6383): 79%
# Finding duplicate polylines (6383): 80%
# Finding duplicate polylines (6383): 81%
# Finding duplicate polylines (6383): 82%
# Finding duplicate polylines (6383): 83%
# Finding duplicate polylines (6383): 84%
# Finding duplicate polylines (6383): 85%
# Finding duplicate polylines (6383): 86%
# Finding duplicate polylines (6383): 87%
# Finding duplicate polylines (6383): 88%
# Finding duplicate polylines (6383): 89%
# Finding duplicate polylines (6383): 90%
# Finding duplicate polylines (6383): 91%
# Finding duplicate polylines (6383): 92%
# Finding duplicate polylines (6383): 93%
# Finding duplicate polylines (6383): 94%
# Finding duplicate polylines (6383): 95%
# Finding duplicate polylines (6383): 96%
# Finding duplicate polylines (6383): 97%
# Finding duplicate polylines (6383): 98%
# Finding duplicate polylines (6383): 99%
# Finding duplicate polylines (6383): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.200s
#
# --- Iteration 20 ---
# .\whitebox_tools.exe --run="Union" --wd="C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136" --input='temp_union_18.shp' --overlay='temp_selec_19.shp' --output='temp_union_19.shp' --snap=0.0 -v --compress_rasters=False
#
# ****************************
# * Welcome to Union         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Finding duplicate polylines (1): 0%
# Finding duplicate polylines (237): 1%
# Finding duplicate polylines (454): 2%
# Finding duplicate polylines (677): 3%
# Finding duplicate polylines (917): 4%
# Finding duplicate polylines (1148): 5%
# Finding duplicate polylines (1391): 6%
# Finding duplicate polylines (1630): 7%
# Finding duplicate polylines (1877): 8%
# Finding duplicate polylines (2124): 9%
# Finding duplicate polylines (2334): 10%
# Finding duplicate polylines (2576): 11%
# Finding duplicate polylines (2819): 12%
# Finding duplicate polylines (3052): 13%
# Finding duplicate polylines (3267): 14%
# Finding duplicate polylines (3507): 15%
# Finding duplicate polylines (3742): 16%
# Finding duplicate polylines (3988): 17%
# Finding duplicate polylines (4236): 18%
# Finding duplicate polylines (4483): 19%
# Finding duplicate polylines (4729): 20%
# Finding duplicate polylines (4976): 21%
# Finding duplicate polylines (5205): 22%
# Finding duplicate polylines (5449): 23%
# Finding duplicate polylines (5687): 24%
# Finding duplicate polylines (5926): 25%
# Finding duplicate polylines (6172): 26%
# Finding duplicate polylines (6386): 27%
# Finding duplicate polylines (6386): 28%
# Finding duplicate polylines (6386): 29%
# Finding duplicate polylines (6386): 30%
# Finding duplicate polylines (6386): 31%
# Finding duplicate polylines (6386): 32%
# Finding duplicate polylines (6386): 33%
# Finding duplicate polylines (6386): 34%
# Finding duplicate polylines (6386): 35%
# Finding duplicate polylines (6386): 36%
# Finding duplicate polylines (6386): 37%
# Finding duplicate polylines (6386): 38%
# Finding duplicate polylines (6386): 39%
# Finding duplicate polylines (6386): 40%
# Finding duplicate polylines (6386): 41%
# Finding duplicate polylines (6386): 42%
# Finding duplicate polylines (6386): 43%
# Finding duplicate polylines (6386): 44%
# Finding duplicate polylines (6386): 45%
# Finding duplicate polylines (6386): 46%
# Finding duplicate polylines (6386): 47%
# Finding duplicate polylines (6386): 48%
# Finding duplicate polylines (6386): 49%
# Finding duplicate polylines (6386): 50%
# Finding duplicate polylines (6386): 51%
# Finding duplicate polylines (6386): 52%
# Finding duplicate polylines (6386): 53%
# Finding duplicate polylines (6386): 54%
# Finding duplicate polylines (6386): 55%
# Finding duplicate polylines (6386): 56%
# Finding duplicate polylines (6386): 57%
# Finding duplicate polylines (6386): 58%
# Finding duplicate polylines (6386): 59%
# Finding duplicate polylines (6386): 60%
# Finding duplicate polylines (6386): 61%
# Finding duplicate polylines (6386): 62%
# Finding duplicate polylines (6386): 63%
# Finding duplicate polylines (6386): 64%
# Finding duplicate polylines (6386): 65%
# Finding duplicate polylines (6386): 66%
# Finding duplicate polylines (6386): 67%
# Finding duplicate polylines (6386): 68%
# Finding duplicate polylines (6386): 69%
# Finding duplicate polylines (6386): 70%
# Finding duplicate polylines (6386): 71%
# Finding duplicate polylines (6386): 72%
# Finding duplicate polylines (6386): 73%
# Finding duplicate polylines (6386): 74%
# Finding duplicate polylines (6386): 75%
# Finding duplicate polylines (6386): 76%
# Finding duplicate polylines (6386): 77%
# Finding duplicate polylines (6386): 78%
# Finding duplicate polylines (6386): 79%
# Finding duplicate polylines (6386): 80%
# Finding duplicate polylines (6386): 81%
# Finding duplicate polylines (6386): 82%
# Finding duplicate polylines (6386): 83%
# Finding duplicate polylines (6386): 84%
# Finding duplicate polylines (6386): 85%
# Finding duplicate polylines (6386): 86%
# Finding duplicate polylines (6386): 87%
# Finding duplicate polylines (6386): 88%
# Finding duplicate polylines (6386): 89%
# Finding duplicate polylines (6386): 90%
# Finding duplicate polylines (6386): 91%
# Finding duplicate polylines (6386): 92%
# Finding duplicate polylines (6386): 93%
# Finding duplicate polylines (6386): 94%
# Finding duplicate polylines (6386): 95%
# Finding duplicate polylines (6386): 96%
# Finding duplicate polylines (6386): 97%
# Finding duplicate polylines (6386): 98%
# Finding duplicate polylines (6386): 99%
# Finding duplicate polylines (6386): 100%
# Saving data...
# Output file written
# Elapsed Time: 0.201s
#
# ---Optimized process completed  ---
# Took 233.96 seconds
# C:\Users\nick_\AppData\Local\Temp\ipykernel_8736\696059023.py:74: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   nuevos_vertices.to_file(puntos_finales_red)

# %%
#Crear drenaje desde puntos finales de manera mas depurada.
wbt = whitebox.WhiteboxTools()
wbt.set_verbose_mode(True)
output_flow = flow_paths_2
wbt.trace_downslope_flowpaths(puntos_finales_red, FP,output=flow_paths_2) 
wbt.raster_streams_to_vector(flow_paths_2,FP,output=stream_manan_final) 
fpl2 = gpd.read_file(stream_manan_final)
fpl2=fpl2.set_crs(epgs)
fpl2.to_file(stream_manan_final)
# Out:
# .\whitebox_tools.exe --run="TraceDownslopeFlowpaths" --seed_pts='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/puntos_finales_red.shp' --d8_pntr='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FP.tif' --output='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/ruta_flujo_2.tif' -v --compress_rasters=False
#
# **************************************
# * Welcome to TraceDownslopeFlowpaths *
# * Powered by WhiteboxTools           *
# * www.whiteboxgeo.com                *
# **************************************
# Reading flow direction data...
# Locating seed points: 0%
# Locating seed points: 1%
# Locating seed points: 2%
# Locating seed points: 3%
# Locating seed points: 4%
# Locating seed points: 5%
# Locating seed points: 6%
# Locating seed points: 7%
# Locating seed points: 8%
# Locating seed points: 9%
# Locating seed points: 10%
# Locating seed points: 11%
# Locating seed points: 12%
# Locating seed points: 13%
# Locating seed points: 14%
# Locating seed points: 15%
# Locating seed points: 16%
# Locating seed points: 17%
# Locating seed points: 18%
# Locating seed points: 19%
# Locating seed points: 20%
# Locating seed points: 21%
# Locating seed points: 22%
# Locating seed points: 23%
# Locating seed points: 24%
# Locating seed points: 25%
# Locating seed points: 26%
# Locating seed points: 27%
# Locating seed points: 28%
# Locating seed points: 29%
# Locating seed points: 30%
# Locating seed points: 31%
# Locating seed points: 32%
# Locating seed points: 33%
# Locating seed points: 34%
# Locating seed points: 35%
# Locating seed points: 36%
# Locating seed points: 37%
# Locating seed points: 38%
# Locating seed points: 39%
# Locating seed points: 40%
# Locating seed points: 41%
# Locating seed points: 42%
# Locating seed points: 43%
# Locating seed points: 44%
# Locating seed points: 45%
# Locating seed points: 46%
# Locating seed points: 47%
# Locating seed points: 48%
# Locating seed points: 49%
# Locating seed points: 50%
# Locating seed points: 51%
# Locating seed points: 52%
# Locating seed points: 53%
# Locating seed points: 54%
# Locating seed points: 55%
# Locating seed points: 56%
# Locating seed points: 57%
# Locating seed points: 58%
# Locating seed points: 59%
# Locating seed points: 60%
# Locating seed points: 61%
# Locating seed points: 62%
# Locating seed points: 63%
# Locating seed points: 64%
# Locating seed points: 65%
# Locating seed points: 66%
# Locating seed points: 67%
# Locating seed points: 68%
# Locating seed points: 69%
# Locating seed points: 70%
# Locating seed points: 71%
# Locating seed points: 72%
# Locating seed points: 73%
# Locating seed points: 74%
# Locating seed points: 75%
# Locating seed points: 76%
# Locating seed points: 77%
# Locating seed points: 78%
# Locating seed points: 79%
# Locating seed points: 80%
# Locating seed points: 81%
# Locating seed points: 82%
# Locating seed points: 83%
# Locating seed points: 84%
# Locating seed points: 85%
# Locating seed points: 86%
# Locating seed points: 87%
# Locating seed points: 88%
# Locating seed points: 89%
# Locating seed points: 90%
# Locating seed points: 91%
# Locating seed points: 92%
# Locating seed points: 93%
# Locating seed points: 94%
# Locating seed points: 95%
# Locating seed points: 96%
# Locating seed points: 97%
# Locating seed points: 98%
# Locating seed points: 99%
# Locating seed points: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Progress: 100%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.273s
# .\whitebox_tools.exe --run="RasterStreamsToVector" --streams='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/ruta_flujo_2.tif' --d8_pntr='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\FP.tif' --output='C:\Users\nick_\OneDrive\Escritorio\Raster\calib_output\Calib_Manan_Sim_12.136/stream_manan_final.shp' -v --compress_rasters=False
#
# ************************************
# * Welcome to RasterStreamsToVector *
# * Powered by WhiteboxTools         *
# * www.whiteboxgeo.com              *
# ************************************
# Reading pointer data...
# Reading streams data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# Progress: 43%
# Progress: 44%
# Progress: 45%
# Progress: 46%
# Progress: 47%
# Progress: 48%
# Progress: 49%
# Progress: 50%
# Progress: 51%
# Progress: 52%
# Progress: 53%
# Progress: 54%
# Progress: 55%
# Progress: 56%
# Progress: 57%
# Progress: 58%
# Progress: 59%
# Progress: 60%
# Progress: 61%
# Progress: 62%
# Progress: 63%
# Progress: 64%
# Progress: 65%
# Progress: 66%
# Progress: 67%
# Progress: 68%
# Progress: 69%
# Progress: 70%
# Progress: 71%
# Progress: 72%
# Progress: 73%
# Progress: 74%
# Progress: 75%
# Progress: 76%
# Progress: 77%
# Progress: 78%
# Progress: 79%
# Progress: 80%
# Progress: 81%
# Progress: 82%
# Progress: 83%
# Progress: 84%
# Progress: 85%
# Progress: 86%
# Progress: 87%
# Progress: 88%
# Progress: 89%
# Progress: 90%
# Progress: 91%
# Progress: 92%
# Progress: 93%
# Progress: 94%
# Progress: 95%
# Progress: 96%
# Progress: 97%
# Progress: 98%
# Progress: 99%
# Saving data...
# Output file written
# Elapsed Time (excluding I/O): 0.126s

# %%
#Intersección para que funcion trabaje bien
drenaje = gpd.read_file(stream_manan_final)       
Dominio_celdas=gdf_domain 
interseccion1 = gpd.overlay(drenaje,Dominio_celdas, how="intersection")
interseccion_mono=interseccion1.explode(index_parts=False).reset_index(drop=True)
interseccion_mono.to_file(carpeta+'/stream_manan_final_inters.shp')

# %%
puntos = gpd.read_file(puntos_finales_red)   # Points of interest with data 
drenaje = gpd.read_file(stream_manan_final_inters)  # Drainage network (polylines)
poligonos = gdf_drn_activas      # Active cells to intersect
buffer_manan=gpd.read_file(buf_manan) #Buffer of springs dots

# %%
###Si ya corrieron todo esto antes, deberian haber solo corrido la primera celda indicada y luego lo que viene

# %%
t0 = time.time()
from tqdm import tqdm    
# Extract the end points from each line
end_points = drenaje.geometry.apply(lambda geom: Point(list(geom.coords)[-1]))
start_points = drenaje.geometry.apply(lambda geom: Point(list(geom.coords)[0]))
# Create a GeoDataFrame of beginnings
gdf_start = gpd.GeoDataFrame({'idx': drenaje.index, 'geometry': start_points}, crs=drenaje.crs)
sindex = gdf_start.sindex  # spatial index for beginnings
# For each line, find who it connects to downstream using the spatial index
tolerancia = 1  # 1 meter
grafo_abajo = defaultdict(list)
for idx, end_pt in zip(drenaje.index, end_points):
    # Find potential matches using the spatial index
    posibles = list(sindex.intersection(end_pt.buffer(tolerancia).bounds))
    for idx2 in posibles:
        start_pt = gdf_start.loc[idx2].geometry
        if end_pt.distance(start_pt) < tolerancia:
            grafo_abajo[idx].append(gdf_start.loc[idx2].idx)
# Assign to global variables
drenaje_global = drenaje
poligonos_global = poligonos
buffer_manan_global = buffer_manan
grafo_abajo_global = grafo_abajo
# List of indexes to process
indices = list(puntos.index)
resultados = []
for idx in tqdm(indices):
    resultado = procesar_punto(idx)
    resultados.append(resultado)
gdf_resultados = gpd.GeoDataFrame(resultados, crs=puntos.crs)
    
#Work on data to include as observations
#Delete rows with null values in ‘name’ or ‘elev_drn’ IF ANY
gdf_clean = gdf_resultados.dropna(subset=["name", "elev_drn"])
# Filter by maximum elev_drn (if there are ties, keep the first one)
gdf_filtrado = gdf_clean.loc[gdf_clean.groupby("name")["elev_drn"].idxmax()]
gdf_filtrado = gdf_filtrado.sort_values(["name", "elev_drn"], ascending=[True, False])
    
#Extract obs
elev=gdf_filtrado[["name","elev_drn"]].copy()
elev['time']=1.0
elev_pivoted = elev.pivot(index='time', columns='name', values='elev_drn')

calib_manan_final =os.path.join(calib_manan_input,'Results')
os.makedirs(calib_manan_final, exist_ok=True)
elev_pivoted.to_csv(os.path.join(calib_manan_final,f"Model_v{version}.Sim_elev.csv"))    
print(f"Demoro {time.time() - t0:.2f} segundos") #time
# Out:
# 100%|██████████| 245/245 [00:15<00:00, 15.42it/s]
# Demoro 19.52 segundos
